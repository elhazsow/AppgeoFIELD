# %%
import pandas as pd
df=pd.read_csv("modis_ndvi_series (1).csv",sep=";")
df=df.set_index("id")

# %%
df.columns=pd.to_datetime(df.columns, format='%Y_%m_%d')

# %%
df.to_csv("data.csv")

# %%
df
# Out:
#      2015-01-01  2015-01-17  2015-02-02  2015-02-18  2015-03-06  2015-03-22  \
# id
# 1          0.44        0.44        0.40        0.35        0.35        0.31
# 2          0.19        0.20        0.22        0.21        0.19        0.19
# 3          0.17        0.18        0.19        0.18        0.17        0.17
# 4          0.16        0.18        0.18        0.18        0.17        0.17
# 5          0.19        0.22        0.21        0.19        0.18        0.19
# ..          ...         ...         ...         ...         ...         ...
# 189        0.27        0.26        0.26        0.24        0.21        0.24
# 190        0.27        0.25        0.25        0.24        0.21        0.25
# 191        0.28        0.25        0.27        0.25        0.23        0.27
# 192        0.23        0.22        0.22        0.20        0.18        0.19
# 193        0.08        0.10        0.15        0.13        0.09        0.08
#
# ...

# %%
# Out:
# 86078
